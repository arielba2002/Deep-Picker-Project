# %% [markdown]
# <a href="https://colab.research.google.com/github/arielba2002/Deep-Picker-Project/blob/main/model/DataScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NBA Statistics Processing
# --------------
# This notebook fetches NBA team and player data from a custom API, then
# organizes and prepares the data for further analysis or modeling (e.g.,
# train/test split). Finally, it saves the raw player data and extracted
# metadata to JSON files.
#
# Reference: NBA Stats API Github
# https://github.com/swar/nba_api

# %% [markdown]
# # Import Modules

# %% [markdown]
# Import required packages

# %%
# =========================
# 1. Imports & Constants
# =========================
# !pip install nba_api

import json
import time
import requests
from collections import defaultdict
from nba_api.stats.static import teams as nba_teams
from nba_api.stats.endpoints import teamyearbyyearstats
from requests.exceptions import ReadTimeout, RequestException
# Out:
# Requirement already satisfied: nba_api in /usr/local/lib/python3.11/dist-packages (1.9.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from nba_api) (2.0.2)
# Requirement already satisfied: pandas>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from nba_api) (2.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /usr/local/lib/python3.11/dist-packages (from nba_api) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->nba_api) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->nba_api) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1.0->nba_api) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.32.3->nba_api) (2025.4.26)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->nba_api) (1.17.0)

# %% [markdown]
# # Team Abbreviation Mapping

# %% [markdown]
# Create a dictionary to standardize team abbreviations across seasons.

# %%
# Mapping for outdated team abbreviations to modern equivalents
TEAM_ABBR_FIX = {
    "NJN": "BKN",  # New Jersey Nets -> Brooklyn Nets
    "BRK": "BKN",  # New Jersey Nets -> Brooklyn Nets
    "CHH": "CHA",  # Charlotte Hornets (original) -> Charlotte Hornets (new)
    "CHO": "CHA",  # Charlotte Hornets (original) -> Charlotte Hornets (new)
    "VAN": "MEM",  # Vancouver Grizzlies -> Memphis Grizzlies
    "SEA": "OKC",  # Seattle SuperSonics -> Oklahoma City Thunder
    "NOH": "NOP",  # New Orleans Hornets -> New Orleans Pelicans
    "NOK": "NOP",  # Temporary NO/OKC Hornets -> Pelicans
    "WSB": "WAS",
    "PHO": "PHX"
}

# %% [markdown]
# # Helper Functions

# %% [markdown]
# ## Fetch Teams by Season

# %% [markdown]
#  Retrieve all teams for each NBA season through the REST API

# %%
def fetch_teams_by_season(api_base_url, seasons):
    teams_by_season = {}
    for season in seasons:
        season_url = f"{api_base_url}/PlayerDataTotals/season/{season}"
        try:
            response = requests.get(season_url)
            response.raise_for_status()
            team_set = {player["team"] for player in response.json()}
            teams_by_season[season] = sorted(team_set)
        except requests.exceptions.RequestException as e:
            print(f"Error fetching teams for season {season}: {e}")
            teams_by_season[season] = []
    return teams_by_season

# %% [markdown]
# ## Fetch Team Season Stats

# %% [markdown]
# Collect comprehensive team statistics with built-in retry logic

# %%
def fetch_team_season_stats(team_abbr, season, max_retries=20, initial_delay=5):
    team_abbr = team_abbr.upper()
    team_abbr = TEAM_ABBR_FIX.get(team_abbr, team_abbr)

    team_info = nba_teams.find_team_by_abbreviation(team_abbr)
    if not team_info:
        print(f"Could not find team info for {team_abbr}")
        return []

    team_id = team_info["id"]
    formatted_season = f"{int(season)}-{str(int(season)+1)[-2:]}"

    for attempt in range(1, max_retries + 1):
        try:
            stats = teamyearbyyearstats.TeamYearByYearStats(
                team_id=team_id,
                per_mode_simple="PerGame",
                league_id="00",
                season_type_all_star="Regular Season",
                timeout=50
            ).get_dict()
            rows = stats["resultSets"][0]["rowSet"]
            headers = stats["resultSets"][0]["headers"]
            for row in rows:
                if row[3] == formatted_season:
                    stats_dict = dict(zip(headers, row))
                    return [
                        stats_dict.get("PTS", 0),
                        stats_dict.get("AST", 0),
                        stats_dict.get("REB", 0),
                        stats_dict.get("BLK", 0),
                        stats_dict.get("STL", 0),
                        stats_dict.get("WIN_PCT", 0),
                        stats_dict.get("CONF_RANK", 0),
                        stats_dict.get("FGM", 0),
                        stats_dict.get("FGA", 0),
                        stats_dict.get("FG3M", 0),
                        stats_dict.get("FG3A", 0),
                        stats_dict.get("FTM", 0),
                        stats_dict.get("FTA", 0),
                        stats_dict.get("OREB", 0),
                        stats_dict.get("DREB", 0),
                        stats_dict.get("PF", 0),
                        stats_dict.get("TOV", 0)
                    ]
            return []
        except ReadTimeout:
            # Exponential backoff - wait longer with each retry
            delay = initial_delay * (2 ** (attempt - 1))
            print(f"Timeout on {team_abbr}_{season}, retry {attempt}/{max_retries} (waiting {delay}s)")
            time.sleep(delay)
        except RequestException as e:
            # Exponential backoff for all request exceptions
            delay = initial_delay * (2 ** (attempt - 1))
            print(f"Retrying in {delay}s...")
            time.sleep(delay)

    print(f"Failed to fetch {team_abbr}_{season} after {max_retries} retries.")
    return []

# %% [markdown]
# ## Fetch Player Stats

# %% [markdown]
# Gather player roster data for each team-season combination

# %%
def fetch_players_in_teamseason(api_base_url, teams_by_season):
    team_season_data = {}
    failed_teams = []

    for season, teams in teams_by_season.items():
        for team in teams:
            team_season_key = f"{team}_{season}" # BOS_1999 (1999-2000)
            print(f"\nFetching data for {team_season_key}")

            # Player stats from previous season
            player_season = season + 1 # Because 1999 is 1998-1999 in the api.
            # 1. get players id's from 1999-2000
            # 2. get those players stats from 1998-1999 whole stats (if the player is in TOT so take his stats from TOT)
            query_url = f"{api_base_url}/PlayerDataTotals/query?team={team}&season={player_season}&pageSize=20"

            try:
                response = requests.get(query_url)
                response.raise_for_status()
                players_data = response.json()
            except requests.exceptions.RequestException as e:
                print(f"Error fetching players for {team} in {player_season}: {e}")
                players_data = []

            time.sleep(1.5)

            # Team stats from current season
            try:
                team_labels = fetch_team_season_stats(team, season)
            except Exception as e:
                print(f"Error fetching team stats for {team_season_key}: {e}")
                team_labels = []
                failed_teams.append(team_season_key)

            team_season_data[team_season_key] = {
                "labels": team_labels,
                "players": players_data
            }

            time.sleep(1.5)

    if failed_teams:
        print("\n❌ Failed team stats for the following keys:")
        for key in failed_teams:
            print(f" - {key}")

    return team_season_data

# %% [markdown]
# ## Create Metadata

# %% [markdown]
#  Generate structured metadata that indexes all teams, players, and their
# relationships across seasons

# %%
def create_metadata(team_season_data):
    all_teams = set()
    all_players = set()
    teams_per_season = defaultdict(set)
    players_per_team_season = {}
    player_stats_attributes = set()
    team_labels = {}

    for team_season_key, data in team_season_data.items():
        team, season = team_season_key.split("_")
        labels = data.get("labels", [])
        players_list = data.get("players", [])

        all_teams.add(team)
        teams_per_season[season].add(team)

        player_names_in_this_team_season = []
        for player_dict in players_list:
            player_name = player_dict.get("playerName", "Unknown")
            all_players.add(player_name)
            player_names_in_this_team_season.append(player_name)
            player_stats_attributes.update(player_dict.keys())

        players_per_team_season[team_season_key] = player_names_in_this_team_season
        team_labels[team_season_key] = labels

    metadata = {
        "all_teams": sorted(all_teams),
        "all_players": sorted(all_players),
        "teams_per_season": {yr: sorted(teams) for yr, teams in teams_per_season.items()},
        "players_per_team_season": players_per_team_season,
        "player_stats_attributes": sorted(player_stats_attributes),
        "team_labels": team_labels
    }

    return metadata

# %% [markdown]
# # Collect NBA Stats by Season

# %% [markdown]
# Define the API endpoint and season range (1996–2025), then call the data collection functions and save the raw team and player data to JSON files.

# %%
API_BASE_URL = "http://rest.nbaapi.com/api"
SEASON_RANGE = range(1996, 2025)

# Get teams by season
teams_by_season_data = fetch_teams_by_season(API_BASE_URL, SEASON_RANGE)

# Count of teams each year
print("\nTeam counts per season:")
for season, teams in teams_by_season_data.items():
    print(f"{season}: {len(teams)}")

# Fetch data
players_in_teamseason_data = fetch_players_in_teamseason(API_BASE_URL, teams_by_season_data)

# Metadata
metadata_dict = create_metadata(players_in_teamseason_data)

# Save output (optional)
with open("team_player_data.json", "w") as f:
    json.dump(players_in_teamseason_data, f, indent=2)

with open("metadata.json", "w") as f:
    json.dump(metadata_dict, f, indent=2)

print("\n✅ Finished processing and saved data.")
# Out:
# Team counts per season:
# 1996: 30
# 1997: 30
# 1998: 30
# 1999: 30
# 2000: 30
# 2001: 30
# 2002: 30
# 2003: 30
# 2004: 30
# 2005: 31
# 2006: 31
# 2007: 31
# 2008: 31
# 2009: 31
# 2010: 31
# 2011: 31
# 2012: 31
# 2013: 31
# 2014: 31
# 2015: 31
# 2016: 31
# 2017: 31
# 2018: 31
# 2019: 31
# 2020: 31
# 2021: 31
# 2022: 31
# 2023: 31
# 2024: 31
#
# Fetching data for ATL_1996
#
# Fetching data for BOS_1996
#
# Fetching data for CHH_1996
#
# Fetching data for CHI_1996
#
# Fetching data for CLE_1996
#
# Fetching data for DAL_1996
#
# Fetching data for DEN_1996
#
# Fetching data for DET_1996
#
# Fetching data for GSW_1996
#
# Fetching data for HOU_1996
#
# Fetching data for IND_1996
#
# Fetching data for LAC_1996
#
# Fetching data for LAL_1996
#
# Fetching data for MIA_1996
#
# Fetching data for MIL_1996
#
# Fetching data for MIN_1996
#
# Fetching data for NJN_1996
#
# Fetching data for NYK_1996
#
# Fetching data for ORL_1996
#
# Fetching data for PHI_1996
#
# Fetching data for PHO_1996
#
# Fetching data for POR_1996
#
# Fetching data for SAC_1996
#
# Fetching data for SAS_1996
#
# Fetching data for SEA_1996
#
# Fetching data for TOR_1996
#
# Fetching data for TOT_1996
# Could not find team info for TOT
#
# Fetching data for UTA_1996
#
# Fetching data for VAN_1996
#
# Fetching data for WSB_1996
#
# Fetching data for ATL_1997
#
# Fetching data for BOS_1997
#
# Fetching data for CHH_1997
#
# Fetching data for CHI_1997
#
# Fetching data for CLE_1997
#
# Fetching data for DAL_1997
#
# Fetching data for DEN_1997
#
# Fetching data for DET_1997
#
# Fetching data for GSW_1997
#
# Fetching data for HOU_1997
#
# Fetching data for IND_1997
#
# Fetching data for LAC_1997
#
# Fetching data for LAL_1997
#
# Fetching data for MIA_1997
#
# Fetching data for MIL_1997
#
# Fetching data for MIN_1997
#
# Fetching data for NJN_1997
#
# Fetching data for NYK_1997
#
# Fetching data for ORL_1997
#
# Fetching data for PHI_1997
#
# Fetching data for PHO_1997
#
# Fetching data for POR_1997
#
# Fetching data for SAC_1997
#
# Fetching data for SAS_1997
#
# Fetching data for SEA_1997
#
# Fetching data for TOR_1997
#
# Fetching data for TOT_1997
# Could not find team info for TOT
#
# Fetching data for UTA_1997
#
# Fetching data for VAN_1997
#
# Fetching data for WSB_1997
# Error fetching players for WSB in 1998: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=WSB&season=1998&pageSize=20
#
# Fetching data for ATL_1998
#
# Fetching data for BOS_1998
#
# Fetching data for CHH_1998
#
# Fetching data for CHI_1998
#
# Fetching data for CLE_1998
#
# Fetching data for DAL_1998
#
# Fetching data for DEN_1998
#
# Fetching data for DET_1998
#
# Fetching data for GSW_1998
#
# Fetching data for HOU_1998
#
# Fetching data for IND_1998
#
# Fetching data for LAC_1998
#
# Fetching data for LAL_1998
#
# Fetching data for MIA_1998
#
# Fetching data for MIL_1998
#
# Fetching data for MIN_1998
#
# Fetching data for NJN_1998
#
# Fetching data for NYK_1998
#
# Fetching data for ORL_1998
#
# Fetching data for PHI_1998
#
# Fetching data for PHO_1998
#
# Fetching data for POR_1998
#
# Fetching data for SAC_1998
#
# Fetching data for SAS_1998
#
# Fetching data for SEA_1998
#
# Fetching data for TOR_1998
#
# Fetching data for TOT_1998
# Could not find team info for TOT
#
# Fetching data for UTA_1998
#
# Fetching data for VAN_1998
#
# Fetching data for WAS_1998
#
# Fetching data for ATL_1999
#
# Fetching data for BOS_1999
#
# Fetching data for CHH_1999
#
# Fetching data for CHI_1999
#
# Fetching data for CLE_1999
#
# Fetching data for DAL_1999
#
# Fetching data for DEN_1999
#
# Fetching data for DET_1999
#
# Fetching data for GSW_1999
#
# Fetching data for HOU_1999
#
# Fetching data for IND_1999
#
# Fetching data for LAC_1999
#
# Fetching data for LAL_1999
#
# Fetching data for MIA_1999
#
# Fetching data for MIL_1999
#
# Fetching data for MIN_1999
#
# Fetching data for NJN_1999
#
# Fetching data for NYK_1999
#
# Fetching data for ORL_1999
#
# Fetching data for PHI_1999
#
# Fetching data for PHO_1999
#
# Fetching data for POR_1999
#
# Fetching data for SAC_1999
#
# Fetching data for SAS_1999
#
# Fetching data for SEA_1999
#
# Fetching data for TOR_1999
#
# Fetching data for TOT_1999
# Could not find team info for TOT
#
# Fetching data for UTA_1999
#
# Fetching data for VAN_1999
#
# Fetching data for WAS_1999
#
# Fetching data for ATL_2000
#
# Fetching data for BOS_2000
#
# Fetching data for CHH_2000
#
# Fetching data for CHI_2000
#
# Fetching data for CLE_2000
#
# Fetching data for DAL_2000
#
# Fetching data for DEN_2000
#
# Fetching data for DET_2000
#
# Fetching data for GSW_2000
#
# Fetching data for HOU_2000
#
# Fetching data for IND_2000
#
# Fetching data for LAC_2000
#
# Fetching data for LAL_2000
#
# Fetching data for MIA_2000
#
# Fetching data for MIL_2000
#
# Fetching data for MIN_2000
#
# Fetching data for NJN_2000
#
# Fetching data for NYK_2000
#
# Fetching data for ORL_2000
#
# Fetching data for PHI_2000
#
# Fetching data for PHO_2000
#
# Fetching data for POR_2000
#
# Fetching data for SAC_2000
#
# Fetching data for SAS_2000
#
# Fetching data for SEA_2000
#
# Fetching data for TOR_2000
#
# Fetching data for TOT_2000
# Could not find team info for TOT
#
# Fetching data for UTA_2000
#
# Fetching data for VAN_2000
#
# Fetching data for WAS_2000
#
# Fetching data for ATL_2001
#
# Fetching data for BOS_2001
#
# Fetching data for CHH_2001
#
# Fetching data for CHI_2001
#
# Fetching data for CLE_2001
#
# Fetching data for DAL_2001
#
# Fetching data for DEN_2001
#
# Fetching data for DET_2001
#
# Fetching data for GSW_2001
#
# Fetching data for HOU_2001
#
# Fetching data for IND_2001
#
# Fetching data for LAC_2001
#
# Fetching data for LAL_2001
#
# Fetching data for MIA_2001
#
# Fetching data for MIL_2001
#
# Fetching data for MIN_2001
#
# Fetching data for NJN_2001
#
# Fetching data for NYK_2001
#
# Fetching data for ORL_2001
#
# Fetching data for PHI_2001
#
# Fetching data for PHO_2001
#
# Fetching data for POR_2001
#
# Fetching data for SAC_2001
#
# Fetching data for SAS_2001
#
# Fetching data for SEA_2001
#
# Fetching data for TOR_2001
#
# Fetching data for TOT_2001
# Could not find team info for TOT
#
# Fetching data for UTA_2001
#
# Fetching data for VAN_2001
# Error fetching players for VAN in 2002: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=VAN&season=2002&pageSize=20
#
# Fetching data for WAS_2001
#
# Fetching data for ATL_2002
#
# Fetching data for BOS_2002
#
# Fetching data for CHH_2002
# Error fetching players for CHH in 2003: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=CHH&season=2003&pageSize=20
#
# Fetching data for CHI_2002
#
# Fetching data for CLE_2002
#
# Fetching data for DAL_2002
#
# Fetching data for DEN_2002
#
# Fetching data for DET_2002
#
# Fetching data for GSW_2002
#
# Fetching data for HOU_2002
#
# Fetching data for IND_2002
#
# Fetching data for LAC_2002
#
# Fetching data for LAL_2002
#
# Fetching data for MEM_2002
#
# Fetching data for MIA_2002
#
# Fetching data for MIL_2002
#
# Fetching data for MIN_2002
#
# Fetching data for NJN_2002
#
# Fetching data for NYK_2002
#
# Fetching data for ORL_2002
#
# Fetching data for PHI_2002
#
# Fetching data for PHO_2002
#
# Fetching data for POR_2002
#
# Fetching data for SAC_2002
#
# Fetching data for SAS_2002
#
# Fetching data for SEA_2002
#
# Fetching data for TOR_2002
#
# Fetching data for TOT_2002
# Could not find team info for TOT
#
# Fetching data for UTA_2002
#
# Fetching data for WAS_2002
#
# Fetching data for ATL_2003
#
# Fetching data for BOS_2003
#
# Fetching data for CHI_2003
#
# Fetching data for CLE_2003
#
# Fetching data for DAL_2003
#
# Fetching data for DEN_2003
#
# Fetching data for DET_2003
#
# Fetching data for GSW_2003
#
# Fetching data for HOU_2003
#
# Fetching data for IND_2003
#
# Fetching data for LAC_2003
#
# Fetching data for LAL_2003
#
# Fetching data for MEM_2003
#
# Fetching data for MIA_2003
#
# Fetching data for MIL_2003
#
# Fetching data for MIN_2003
#
# Fetching data for NJN_2003
#
# Fetching data for NOH_2003
#
# Fetching data for NYK_2003
#
# Fetching data for ORL_2003
#
# Fetching data for PHI_2003
#
# Fetching data for PHO_2003
#
# Fetching data for POR_2003
#
# Fetching data for SAC_2003
#
# Fetching data for SAS_2003
#
# Fetching data for SEA_2003
#
# Fetching data for TOR_2003
#
# Fetching data for TOT_2003
# Could not find team info for TOT
#
# Fetching data for UTA_2003
#
# Fetching data for WAS_2003
#
# Fetching data for ATL_2004
#
# Fetching data for BOS_2004
#
# Fetching data for CHI_2004
#
# Fetching data for CLE_2004
#
# Fetching data for DAL_2004
#
# Fetching data for DEN_2004
#
# Fetching data for DET_2004
#
# Fetching data for GSW_2004
#
# Fetching data for HOU_2004
#
# Fetching data for IND_2004
#
# Fetching data for LAC_2004
#
# Fetching data for LAL_2004
#
# Fetching data for MEM_2004
#
# Fetching data for MIA_2004
#
# Fetching data for MIL_2004
#
# Fetching data for MIN_2004
#
# Fetching data for NJN_2004
#
# Fetching data for NOH_2004
#
# Fetching data for NYK_2004
#
# Fetching data for ORL_2004
#
# Fetching data for PHI_2004
#
# Fetching data for PHO_2004
#
# Fetching data for POR_2004
#
# Fetching data for SAC_2004
#
# Fetching data for SAS_2004
#
# Fetching data for SEA_2004
#
# Fetching data for TOR_2004
#
# Fetching data for TOT_2004
# Could not find team info for TOT
#
# Fetching data for UTA_2004
#
# Fetching data for WAS_2004
#
# Fetching data for ATL_2005
#
# Fetching data for BOS_2005
#
# Fetching data for CHA_2005
#
# Fetching data for CHI_2005
#
# Fetching data for CLE_2005
#
# Fetching data for DAL_2005
#
# Fetching data for DEN_2005
#
# Fetching data for DET_2005
#
# Fetching data for GSW_2005
#
# Fetching data for HOU_2005
#
# Fetching data for IND_2005
#
# Fetching data for LAC_2005
#
# Fetching data for LAL_2005
#
# Fetching data for MEM_2005
#
# Fetching data for MIA_2005
#
# Fetching data for MIL_2005
#
# Fetching data for MIN_2005
#
# Fetching data for NJN_2005
#
# Fetching data for NOH_2005
# Error fetching players for NOH in 2006: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=NOH&season=2006&pageSize=20
#
# Fetching data for NYK_2005
#
# Fetching data for ORL_2005
#
# Fetching data for PHI_2005
#
# Fetching data for PHO_2005
#
# Fetching data for POR_2005
#
# Fetching data for SAC_2005
#
# Fetching data for SAS_2005
#
# Fetching data for SEA_2005
#
# Fetching data for TOR_2005
#
# Fetching data for TOT_2005
# Could not find team info for TOT
#
# Fetching data for UTA_2005
#
# Fetching data for WAS_2005
#
# Fetching data for ATL_2006
#
# Fetching data for BOS_2006
#
# Fetching data for CHA_2006
#
# Fetching data for CHI_2006
#
# Fetching data for CLE_2006
#
# Fetching data for DAL_2006
#
# Fetching data for DEN_2006
#
# Fetching data for DET_2006
#
# Fetching data for GSW_2006
#
# Fetching data for HOU_2006
#
# Fetching data for IND_2006
#
# Fetching data for LAC_2006
#
# Fetching data for LAL_2006
#
# Fetching data for MEM_2006
#
# Fetching data for MIA_2006
#
# Fetching data for MIL_2006
#
# Fetching data for MIN_2006
#
# Fetching data for NJN_2006
#
# Fetching data for NOK_2006
#
# Fetching data for NYK_2006
#
# Fetching data for ORL_2006
#
# Fetching data for PHI_2006
#
# Fetching data for PHO_2006
#
# Fetching data for POR_2006
#
# Fetching data for SAC_2006
#
# Fetching data for SAS_2006
#
# Fetching data for SEA_2006
#
# Fetching data for TOR_2006
#
# Fetching data for TOT_2006
# Could not find team info for TOT
#
# Fetching data for UTA_2006
#
# Fetching data for WAS_2006
#
# Fetching data for ATL_2007
#
# Fetching data for BOS_2007
#
# Fetching data for CHA_2007
#
# Fetching data for CHI_2007
#
# Fetching data for CLE_2007
#
# Fetching data for DAL_2007
#
# Fetching data for DEN_2007
#
# Fetching data for DET_2007
#
# Fetching data for GSW_2007
#
# Fetching data for HOU_2007
#
# Fetching data for IND_2007
#
# Fetching data for LAC_2007
#
# Fetching data for LAL_2007
#
# Fetching data for MEM_2007
#
# Fetching data for MIA_2007
#
# Fetching data for MIL_2007
#
# Fetching data for MIN_2007
#
# Fetching data for NJN_2007
#
# Fetching data for NOK_2007
# Error fetching players for NOK in 2008: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=NOK&season=2008&pageSize=20
#
# Fetching data for NYK_2007
#
# Fetching data for ORL_2007
#
# Fetching data for PHI_2007
#
# Fetching data for PHO_2007
#
# Fetching data for POR_2007
#
# Fetching data for SAC_2007
#
# Fetching data for SAS_2007
#
# Fetching data for SEA_2007
#
# Fetching data for TOR_2007
#
# Fetching data for TOT_2007
# Could not find team info for TOT
#
# Fetching data for UTA_2007
#
# Fetching data for WAS_2007
#
# Fetching data for ATL_2008
#
# Fetching data for BOS_2008
#
# Fetching data for CHA_2008
#
# Fetching data for CHI_2008
#
# Fetching data for CLE_2008
#
# Fetching data for DAL_2008
#
# Fetching data for DEN_2008
#
# Fetching data for DET_2008
#
# Fetching data for GSW_2008
#
# Fetching data for HOU_2008
#
# Fetching data for IND_2008
#
# Fetching data for LAC_2008
#
# Fetching data for LAL_2008
#
# Fetching data for MEM_2008
#
# Fetching data for MIA_2008
#
# Fetching data for MIL_2008
#
# Fetching data for MIN_2008
#
# Fetching data for NJN_2008
#
# Fetching data for NOH_2008
#
# Fetching data for NYK_2008
#
# Fetching data for ORL_2008
#
# Fetching data for PHI_2008
#
# Fetching data for PHO_2008
#
# Fetching data for POR_2008
#
# Fetching data for SAC_2008
#
# Fetching data for SAS_2008
#
# Fetching data for SEA_2008
# Error fetching players for SEA in 2009: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=SEA&season=2009&pageSize=20
#
# Fetching data for TOR_2008
#
# Fetching data for TOT_2008
# Could not find team info for TOT
#
# Fetching data for UTA_2008
#
# Fetching data for WAS_2008
#
# Fetching data for ATL_2009
#
# Fetching data for BOS_2009
#
# Fetching data for CHA_2009
#
# Fetching data for CHI_2009
#
# Fetching data for CLE_2009
#
# Fetching data for DAL_2009
#
# Fetching data for DEN_2009
#
# Fetching data for DET_2009
#
# Fetching data for GSW_2009
#
# Fetching data for HOU_2009
#
# Fetching data for IND_2009
#
# Fetching data for LAC_2009
#
# Fetching data for LAL_2009
#
# Fetching data for MEM_2009
#
# Fetching data for MIA_2009
#
# Fetching data for MIL_2009
#
# Fetching data for MIN_2009
#
# Fetching data for NJN_2009
#
# Fetching data for NOH_2009
#
# Fetching data for NYK_2009
#
# Fetching data for OKC_2009
#
# Fetching data for ORL_2009
#
# Fetching data for PHI_2009
#
# Fetching data for PHO_2009
#
# Fetching data for POR_2009
#
# Fetching data for SAC_2009
#
# Fetching data for SAS_2009
#
# Fetching data for TOR_2009
#
# Fetching data for TOT_2009
# Could not find team info for TOT
#
# Fetching data for UTA_2009
#
# Fetching data for WAS_2009
#
# Fetching data for ATL_2010
#
# Fetching data for BOS_2010
#
# Fetching data for CHA_2010
#
# Fetching data for CHI_2010
#
# Fetching data for CLE_2010
#
# Fetching data for DAL_2010
#
# Fetching data for DEN_2010
#
# Fetching data for DET_2010
#
# Fetching data for GSW_2010
#
# Fetching data for HOU_2010
#
# Fetching data for IND_2010
#
# Fetching data for LAC_2010
#
# Fetching data for LAL_2010
#
# Fetching data for MEM_2010
#
# Fetching data for MIA_2010
#
# Fetching data for MIL_2010
#
# Fetching data for MIN_2010
#
# Fetching data for NJN_2010
#
# Fetching data for NOH_2010
#
# Fetching data for NYK_2010
#
# Fetching data for OKC_2010
#
# Fetching data for ORL_2010
#
# Fetching data for PHI_2010
#
# Fetching data for PHO_2010
#
# Fetching data for POR_2010
#
# Fetching data for SAC_2010
#
# Fetching data for SAS_2010
#
# Fetching data for TOR_2010
#
# Fetching data for TOT_2010
# Could not find team info for TOT
#
# Fetching data for UTA_2010
#
# Fetching data for WAS_2010
#
# Fetching data for ATL_2011
#
# Fetching data for BOS_2011
#
# Fetching data for CHA_2011
#
# Fetching data for CHI_2011
#
# Fetching data for CLE_2011
#
# Fetching data for DAL_2011
#
# Fetching data for DEN_2011
#
# Fetching data for DET_2011
#
# Fetching data for GSW_2011
#
# Fetching data for HOU_2011
#
# Fetching data for IND_2011
#
# Fetching data for LAC_2011
#
# Fetching data for LAL_2011
#
# Fetching data for MEM_2011
#
# Fetching data for MIA_2011
#
# Fetching data for MIL_2011
#
# Fetching data for MIN_2011
#
# Fetching data for NJN_2011
#
# Fetching data for NOH_2011
#
# Fetching data for NYK_2011
#
# Fetching data for OKC_2011
#
# Fetching data for ORL_2011
#
# Fetching data for PHI_2011
#
# Fetching data for PHO_2011
#
# Fetching data for POR_2011
#
# Fetching data for SAC_2011
#
# Fetching data for SAS_2011
#
# Fetching data for TOR_2011
#
# Fetching data for TOT_2011
# Could not find team info for TOT
#
# Fetching data for UTA_2011
#
# Fetching data for WAS_2011
#
# Fetching data for ATL_2012
#
# Fetching data for BOS_2012
#
# Fetching data for CHA_2012
#
# Fetching data for CHI_2012
#
# Fetching data for CLE_2012
#
# Fetching data for DAL_2012
#
# Fetching data for DEN_2012
#
# Fetching data for DET_2012
#
# Fetching data for GSW_2012
#
# Fetching data for HOU_2012
#
# Fetching data for IND_2012
#
# Fetching data for LAC_2012
#
# Fetching data for LAL_2012
#
# Fetching data for MEM_2012
#
# Fetching data for MIA_2012
#
# Fetching data for MIL_2012
#
# Fetching data for MIN_2012
#
# Fetching data for NJN_2012
# Error fetching players for NJN in 2013: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=NJN&season=2013&pageSize=20
#
# Fetching data for NOH_2012
#
# Fetching data for NYK_2012
#
# Fetching data for OKC_2012
#
# Fetching data for ORL_2012
#
# Fetching data for PHI_2012
#
# Fetching data for PHO_2012
#
# Fetching data for POR_2012
#
# Fetching data for SAC_2012
#
# Fetching data for SAS_2012
#
# Fetching data for TOR_2012
#
# Fetching data for TOT_2012
# Could not find team info for TOT
#
# Fetching data for UTA_2012
#
# Fetching data for WAS_2012
#
# Fetching data for ATL_2013
#
# Fetching data for BOS_2013
#
# Fetching data for BRK_2013
#
# Fetching data for CHA_2013
#
# Fetching data for CHI_2013
#
# Fetching data for CLE_2013
#
# Fetching data for DAL_2013
#
# Fetching data for DEN_2013
#
# Fetching data for DET_2013
#
# Fetching data for GSW_2013
#
# Fetching data for HOU_2013
#
# Fetching data for IND_2013
#
# Fetching data for LAC_2013
#
# Fetching data for LAL_2013
#
# Fetching data for MEM_2013
#
# Fetching data for MIA_2013
#
# Fetching data for MIL_2013
#
# Fetching data for MIN_2013
#
# Fetching data for NOH_2013
# Error fetching players for NOH in 2014: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=NOH&season=2014&pageSize=20
#
# Fetching data for NYK_2013
#
# Fetching data for OKC_2013
#
# Fetching data for ORL_2013
#
# Fetching data for PHI_2013
#
# Fetching data for PHO_2013
#
# Fetching data for POR_2013
#
# Fetching data for SAC_2013
#
# Fetching data for SAS_2013
#
# Fetching data for TOR_2013
#
# Fetching data for TOT_2013
# Could not find team info for TOT
#
# Fetching data for UTA_2013
#
# Fetching data for WAS_2013
#
# Fetching data for ATL_2014
#
# Fetching data for BOS_2014
#
# Fetching data for BRK_2014
#
# Fetching data for CHA_2014
# Error fetching players for CHA in 2015: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=CHA&season=2015&pageSize=20
#
# Fetching data for CHI_2014
#
# Fetching data for CLE_2014
#
# Fetching data for DAL_2014
#
# Fetching data for DEN_2014
#
# Fetching data for DET_2014
#
# Fetching data for GSW_2014
#
# Fetching data for HOU_2014
#
# Fetching data for IND_2014
#
# Fetching data for LAC_2014
#
# Fetching data for LAL_2014
#
# Fetching data for MEM_2014
#
# Fetching data for MIA_2014
#
# Fetching data for MIL_2014
#
# Fetching data for MIN_2014
#
# Fetching data for NOP_2014
#
# Fetching data for NYK_2014
#
# Fetching data for OKC_2014
#
# Fetching data for ORL_2014
#
# Fetching data for PHI_2014
#
# Fetching data for PHO_2014
#
# Fetching data for POR_2014
#
# Fetching data for SAC_2014
#
# Fetching data for SAS_2014
#
# Fetching data for TOR_2014
#
# Fetching data for TOT_2014
# Could not find team info for TOT
#
# Fetching data for UTA_2014
#
# Fetching data for WAS_2014
#
# Fetching data for ATL_2015
#
# Fetching data for BOS_2015
#
# Fetching data for BRK_2015
#
# Fetching data for CHI_2015
#
# Fetching data for CHO_2015
#
# Fetching data for CLE_2015
#
# Fetching data for DAL_2015
#
# Fetching data for DEN_2015
#
# Fetching data for DET_2015
#
# Fetching data for GSW_2015
#
# Fetching data for HOU_2015
#
# Fetching data for IND_2015
#
# Fetching data for LAC_2015
#
# Fetching data for LAL_2015
#
# Fetching data for MEM_2015
#
# Fetching data for MIA_2015
#
# Fetching data for MIL_2015
#
# Fetching data for MIN_2015
#
# Fetching data for NOP_2015
#
# Fetching data for NYK_2015
#
# Fetching data for OKC_2015
#
# Fetching data for ORL_2015
#
# Fetching data for PHI_2015
#
# Fetching data for PHO_2015
#
# Fetching data for POR_2015
#
# Fetching data for SAC_2015
#
# Fetching data for SAS_2015
#
# Fetching data for TOR_2015
#
# Fetching data for TOT_2015
# Could not find team info for TOT
#
# Fetching data for UTA_2015
#
# Fetching data for WAS_2015
#
# Fetching data for ATL_2016
#
# Fetching data for BOS_2016
#
# Fetching data for BRK_2016
#
# Fetching data for CHI_2016
#
# Fetching data for CHO_2016
#
# Fetching data for CLE_2016
#
# Fetching data for DAL_2016
#
# Fetching data for DEN_2016
#
# Fetching data for DET_2016
#
# Fetching data for GSW_2016
#
# Fetching data for HOU_2016
#
# Fetching data for IND_2016
# Timeout on IND_2016, retry 1/20 (waiting 5s)
# Timeout on IND_2016, retry 2/20 (waiting 10s)
# Timeout on IND_2016, retry 3/20 (waiting 20s)
#
# Fetching data for LAC_2016
#
# Fetching data for LAL_2016
#
# Fetching data for MEM_2016
#
# Fetching data for MIA_2016
#
# Fetching data for MIL_2016
#
# Fetching data for MIN_2016
#
# Fetching data for NOP_2016
#
# Fetching data for NYK_2016
#
# Fetching data for OKC_2016
#
# Fetching data for ORL_2016
#
# Fetching data for PHI_2016
#
# Fetching data for PHO_2016
#
# Fetching data for POR_2016
#
# Fetching data for SAC_2016
#
# Fetching data for SAS_2016
#
# Fetching data for TOR_2016
#
# Fetching data for TOT_2016
# Could not find team info for TOT
#
# Fetching data for UTA_2016
#
# Fetching data for WAS_2016
#
# Fetching data for ATL_2017
#
# Fetching data for BOS_2017
#
# Fetching data for BRK_2017
#
# Fetching data for CHI_2017
#
# Fetching data for CHO_2017
#
# Fetching data for CLE_2017
#
# Fetching data for DAL_2017
#
# Fetching data for DEN_2017
#
# Fetching data for DET_2017
#
# Fetching data for GSW_2017
#
# Fetching data for HOU_2017
#
# Fetching data for IND_2017
#
# Fetching data for LAC_2017
#
# Fetching data for LAL_2017
#
# Fetching data for MEM_2017
#
# Fetching data for MIA_2017
#
# Fetching data for MIL_2017
#
# Fetching data for MIN_2017
#
# Fetching data for NOP_2017
#
# Fetching data for NYK_2017
#
# Fetching data for OKC_2017
#
# Fetching data for ORL_2017
#
# Fetching data for PHI_2017
#
# Fetching data for PHO_2017
#
# Fetching data for POR_2017
#
# Fetching data for SAC_2017
#
# Fetching data for SAS_2017
#
# Fetching data for TOR_2017
#
# Fetching data for TOT_2017
# Could not find team info for TOT
#
# Fetching data for UTA_2017
#
# Fetching data for WAS_2017
#
# Fetching data for ATL_2018
#
# Fetching data for BOS_2018
#
# Fetching data for BRK_2018
#
# Fetching data for CHI_2018
#
# Fetching data for CHO_2018
#
# Fetching data for CLE_2018
#
# Fetching data for DAL_2018
#
# Fetching data for DEN_2018
#
# Fetching data for DET_2018
#
# Fetching data for GSW_2018
#
# Fetching data for HOU_2018
#
# Fetching data for IND_2018
#
# Fetching data for LAC_2018
#
# Fetching data for LAL_2018
#
# Fetching data for MEM_2018
#
# Fetching data for MIA_2018
#
# Fetching data for MIL_2018
#
# Fetching data for MIN_2018
#
# Fetching data for NOP_2018
#
# Fetching data for NYK_2018
#
# Fetching data for OKC_2018
#
# Fetching data for ORL_2018
#
# Fetching data for PHI_2018
#
# Fetching data for PHO_2018
#
# Fetching data for POR_2018
#
# Fetching data for SAC_2018
#
# Fetching data for SAS_2018
#
# Fetching data for TOR_2018
#
# Fetching data for TOT_2018
# Could not find team info for TOT
#
# Fetching data for UTA_2018
#
# Fetching data for WAS_2018
#
# Fetching data for ATL_2019
#
# Fetching data for BOS_2019
#
# Fetching data for BRK_2019
#
# Fetching data for CHI_2019
#
# Fetching data for CHO_2019
#
# Fetching data for CLE_2019
#
# Fetching data for DAL_2019
#
# Fetching data for DEN_2019
#
# Fetching data for DET_2019
#
# Fetching data for GSW_2019
#
# Fetching data for HOU_2019
#
# Fetching data for IND_2019
#
# Fetching data for LAC_2019
#
# Fetching data for LAL_2019
#
# Fetching data for MEM_2019
#
# Fetching data for MIA_2019
#
# Fetching data for MIL_2019
#
# Fetching data for MIN_2019
#
# Fetching data for NOP_2019
#
# Fetching data for NYK_2019
#
# Fetching data for OKC_2019
#
# Fetching data for ORL_2019
#
# Fetching data for PHI_2019
#
# Fetching data for PHO_2019
#
# Fetching data for POR_2019
#
# Fetching data for SAC_2019
#
# Fetching data for SAS_2019
#
# Fetching data for TOR_2019
#
# Fetching data for TOT_2019
# Could not find team info for TOT
#
# Fetching data for UTA_2019
#
# Fetching data for WAS_2019
#
# Fetching data for ATL_2020
#
# Fetching data for BOS_2020
#
# Fetching data for BRK_2020
#
# Fetching data for CHI_2020
#
# Fetching data for CHO_2020
#
# Fetching data for CLE_2020
#
# Fetching data for DAL_2020
#
# Fetching data for DEN_2020
#
# Fetching data for DET_2020
#
# Fetching data for GSW_2020
#
# Fetching data for HOU_2020
#
# Fetching data for IND_2020
# Timeout on IND_2020, retry 1/20 (waiting 5s)
# Timeout on IND_2020, retry 2/20 (waiting 10s)
# Timeout on IND_2020, retry 3/20 (waiting 20s)
# Timeout on IND_2020, retry 4/20 (waiting 40s)
# Timeout on IND_2020, retry 5/20 (waiting 80s)
# Timeout on IND_2020, retry 6/20 (waiting 160s)
# Timeout on IND_2020, retry 7/20 (waiting 320s)
# Timeout on IND_2020, retry 8/20 (waiting 640s)
# Timeout on IND_2020, retry 9/20 (waiting 1280s)
#
# Fetching data for LAC_2020
#
# Fetching data for LAL_2020
#
# Fetching data for MEM_2020
#
# Fetching data for MIA_2020
#
# Fetching data for MIL_2020
#
# Fetching data for MIN_2020
#
# Fetching data for NOP_2020
#
# Fetching data for NYK_2020
#
# Fetching data for OKC_2020
#
# Fetching data for ORL_2020
#
# Fetching data for PHI_2020
#
# Fetching data for PHO_2020
#
# Fetching data for POR_2020
#
# Fetching data for SAC_2020
#
# Fetching data for SAS_2020
#
# Fetching data for TOR_2020
#
# Fetching data for TOT_2020
# Could not find team info for TOT
#
# Fetching data for UTA_2020
#
# Fetching data for WAS_2020
#
# Fetching data for ATL_2021
#
# Fetching data for BOS_2021
#
# Fetching data for BRK_2021
#
# Fetching data for CHI_2021
#
# Fetching data for CHO_2021
#
# Fetching data for CLE_2021
#
# Fetching data for DAL_2021
#
# Fetching data for DEN_2021
#
# Fetching data for DET_2021
#
# Fetching data for GSW_2021
#
# Fetching data for HOU_2021
#
# Fetching data for IND_2021
#
# Fetching data for LAC_2021
#
# Fetching data for LAL_2021
#
# Fetching data for MEM_2021
#
# Fetching data for MIA_2021
#
# Fetching data for MIL_2021
#
# Fetching data for MIN_2021
#
# Fetching data for NOP_2021
#
# Fetching data for NYK_2021
#
# Fetching data for OKC_2021
#
# Fetching data for ORL_2021
#
# Fetching data for PHI_2021
#
# Fetching data for PHO_2021
#
# Fetching data for POR_2021
#
# Fetching data for SAC_2021
#
# Fetching data for SAS_2021
#
# Fetching data for TOR_2021
#
# Fetching data for TOT_2021
# Could not find team info for TOT
#
# Fetching data for UTA_2021
#
# Fetching data for WAS_2021
#
# Fetching data for ATL_2022
#
# Fetching data for BOS_2022
#
# Fetching data for BRK_2022
#
# Fetching data for CHI_2022
#
# Fetching data for CHO_2022
#
# Fetching data for CLE_2022
#
# Fetching data for DAL_2022
#
# Fetching data for DEN_2022
#
# Fetching data for DET_2022
#
# Fetching data for GSW_2022
#
# Fetching data for HOU_2022
#
# Fetching data for IND_2022
#
# Fetching data for LAC_2022
#
# Fetching data for LAL_2022
#
# Fetching data for MEM_2022
#
# Fetching data for MIA_2022
#
# Fetching data for MIL_2022
#
# Fetching data for MIN_2022
#
# Fetching data for NOP_2022
#
# Fetching data for NYK_2022
#
# Fetching data for OKC_2022
#
# Fetching data for ORL_2022
#
# Fetching data for PHI_2022
#
# Fetching data for PHO_2022
#
# Fetching data for POR_2022
#
# Fetching data for SAC_2022
#
# Fetching data for SAS_2022
#
# Fetching data for TOR_2022
#
# Fetching data for TOT_2022
# Could not find team info for TOT
#
# Fetching data for UTA_2022
#
# Fetching data for WAS_2022
#
# Fetching data for ATL_2023
#
# Fetching data for BOS_2023
#
# Fetching data for BRK_2023
#
# Fetching data for CHI_2023
#
# Fetching data for CHO_2023
#
# Fetching data for CLE_2023
#
# Fetching data for DAL_2023
#
# Fetching data for DEN_2023
#
# Fetching data for DET_2023
#
# Fetching data for GSW_2023
#
# Fetching data for HOU_2023
#
# Fetching data for IND_2023
#
# Fetching data for LAC_2023
#
# Fetching data for LAL_2023
#
# Fetching data for MEM_2023
#
# Fetching data for MIA_2023
#
# Fetching data for MIL_2023
#
# Fetching data for MIN_2023
#
# Fetching data for NOP_2023
#
# Fetching data for NYK_2023
#
# Fetching data for OKC_2023
#
# Fetching data for ORL_2023
#
# Fetching data for PHI_2023
#
# Fetching data for PHO_2023
#
# Fetching data for POR_2023
#
# Fetching data for SAC_2023
#
# Fetching data for SAS_2023
#
# Fetching data for TOR_2023
#
# Fetching data for TOT_2023
# Could not find team info for TOT
#
# Fetching data for UTA_2023
#
# Fetching data for WAS_2023
#
# Fetching data for ATL_2024
#
# Fetching data for BOS_2024
#
# Fetching data for BRK_2024
#
# Fetching data for CHI_2024
#
# Fetching data for CHO_2024
#
# Fetching data for CLE_2024
#
# Fetching data for DAL_2024
#
# Fetching data for DEN_2024
#
# Fetching data for DET_2024
#
# Fetching data for GSW_2024
#
# Fetching data for HOU_2024
#
# Fetching data for IND_2024
#
# Fetching data for LAC_2024
#
# Fetching data for LAL_2024
#
# Fetching data for MEM_2024
#
# Fetching data for MIA_2024
#
# Fetching data for MIL_2024
#
# Fetching data for MIN_2024
#
# Fetching data for NOP_2024
#
# Fetching data for NYK_2024
#
# Fetching data for OKC_2024
#
# Fetching data for ORL_2024
#
# Fetching data for PHI_2024
#
# Fetching data for PHO_2024
#
# Fetching data for POR_2024
#
# Fetching data for SAC_2024
#
# Fetching data for SAS_2024
#
# Fetching data for TOR_2024
#
# Fetching data for TOT_2024
# Error fetching players for TOT in 2025: 404 Client Error: Not Found for url: http://rest.nbaapi.com/api/PlayerDataTotals/query?team=TOT&season=2025&pageSize=20
# Could not find team info for TOT
#
# Fetching data for UTA_2024
#
# Fetching data for WAS_2024
#
# ✅ Finished processing and saved data.

# %% [markdown]
# # Generate Previous Year Data

# %% [markdown]
# Creates historical performance tracking by linking current team rosters to players' previous season statistics

# %%
data = players_in_teamseason_data
previous_year_data = {}

for key, value in data.items():
    previous_year_data[key] = {}
    previous_year_data[key]['labels'] = value['labels']
    previous_year_data[key]['players'] = []

    # get the previous year from the key
    previous_year = key.split('_')[1]
    previous_year = str(int(previous_year) - 1) ## str(1998)


    # search for the player in the previous year and add the player's data to the previous_year_data dictionary
    for player in value['players']:

        flag = 0
        player_id = player['playerId']
        # check if that player exists in the team of TOT previous_year, if it does, take the player from there
        if 'TOT_' + previous_year in data:
            for player_2 in data['TOT_' + previous_year]['players']:
                if player_2['playerId'] == player_id:
                    previous_year_data[key]['players'].append(player_2)
                    flag = 1
                    break

        # ONLY IF player was not found in TOT, search in all teams
        if flag == 0:
            for key_2, value_2 in data.items():
                if previous_year in key_2:
                    for player_2 in value_2['players']:
                        if player_2['playerId'] == player_id:
                            previous_year_data[key]['players'].append(player_2)
                            flag = 1
                            break
        if flag == 0:
            print("player " + player['playerName'] + str(player['season']-1) + "not found")
# Out:
# player Alan Henderson1996not found
# player Anthony Miller1996not found
# player Christian Laettner1996not found
# player Darrin Hancock1996not found
# player Derrick Alston1996not found
# player Dikembe Mutombo*1996not found
# player Donnie Boyce1996not found
# player Eldridge Recasner1996not found
for key, value in previous_year_data.items():
    top_8_players_previous_year[key] = {}
    top_8_players_previous_year[key]['labels'] =  value['labels']
    top_8_players_previous_year[key]['players'] = []

    # sort the players based on the minutes played
    value['players'] = sorted(value['players'], key=lambda x: x['minutesPg'], reverse=True)
    # add the top 8 players to the top_8_players_previous_year dictionary
    top_8_players_previous_year[key]['players'] = value['players'][:8]


previous_year_data = top_8_players_previous_year

# %% [markdown]
# ## Save Final Data

# %% [markdown]
#  Exports the final processed dataset to a JSON file

# %%
with open('previous_year_data_modified.json', 'w') as file:
    json.dump(previous_year_data, file)

# %% [markdown]
# # Validate the Results

# %%
# Load the JSON data
with open('previous_year_data_modified.json', 'r') as file:
    data = json.load(file)

# Initialize arrays to store the results
players_per_team = []
teams_per_year = {}
labels_per_team = []
team_year_keys = []

# Process the data
for team_year, team_data in data.items():
    # Skip teams from 1996 and TOT teams.
    team = team_year.split('_')[0]
    year = team_year.split('_')[1]

    if year == "1996" or team == "TOT":
        continue

    team_year_keys.append(team_year)

    # Count number of players in this team
    if "players" in team_data:
        players_per_team.append(len(team_data["players"]))
        if len(team_data["players"]) < 8:
            print(f"Team {team_year} has less than 8 players. they have {len(team_data['players'])} players.")
    else:
        players_per_team.append(0)
        print(f"Team {team_year} has no players.")

    # Count number of labels in this team
    if "labels" in team_data:
        labels_per_team.append(len(team_data["labels"]))
        if len(team_data["labels"]) < 17:
            print(f"Team {team_year} has less then 17 labels.")
    else:
        labels_per_team.append(0)
        print(f"Team {team_year} has no labels.")

    # Update teams count per year
    if year not in teams_per_year:
        teams_per_year[year] = 0
    teams_per_year[year] += 1

# Convert teams_per_year dictionary to a list ordered by year
sorted_years = sorted(teams_per_year.keys())
teams_per_year_list = [teams_per_year[year] for year in sorted_years]

# Print the results
print("Number of players in each team (excluding 1996 teams and TOT teams):")
print(players_per_team)

print("\nNumber of teams in each year (excluding 1996 and TOT teams):")
print(teams_per_year_list)

print("\nNumber of labels for each team (excluding 1996 teams and TOT teams):")
print(labels_per_team)
# Out:
# Team WSB_1997 has less than 8 players. they have 0 players.
# Team WAS_1998 has less than 8 players. they have 4 players.
# Team VAN_2001 has less than 8 players. they have 0 players.
# Team CHH_2002 has less than 8 players. they have 0 players.
# Team CHH_2002 has less then 17 labels.
# Team MEM_2002 has less than 8 players. they have 3 players.
# Team NOH_2003 has less than 8 players. they have 6 players.
# Team CHA_2005 has less than 8 players. they have 4 players.
# Team NOH_2005 has less than 8 players. they have 0 players.
# Team NOK_2007 has less than 8 players. they have 0 players.
# Team NOH_2008 has less than 8 players. they have 5 players.
# Team SEA_2008 has less than 8 players. they have 0 players.
# Team OKC_2009 has less than 8 players. they have 5 players.
# Team NJN_2012 has less than 8 players. they have 0 players.
# Team NOH_2013 has less than 8 players. they have 0 players.
# Team CHA_2014 has less than 8 players. they have 0 players.
# Number of players in each team (excluding 1996 teams and TOT teams):
# [8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 4, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 0, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 3, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 4, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 5, 8, 8, 8, 8, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 5, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 0, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]
#
# Number of teams in each year (excluding 1996 and TOT teams):
# [29, 29, 29, 29, 29, 29, 29, 29, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30, 30]
#
# Number of labels for each team (excluding 1996 teams and TOT teams):
# [17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 0, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17]
